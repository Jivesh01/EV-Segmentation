# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Electric_Vehicle_Data.csv')
df
# Out:
#      Unnamed: 0  Age       City Profession Marital Status      Education  \
# 0             0   30      Nabha        NaN         Single       Graduate
# 1             1   27       Pune        NaN         Single       Graduate
# 2             2   32  Kashipur         NaN         Single       Graduate
# 3             3   55       Pune   Business         Single       Graduate
# 4             4   26     Satara        NaN         Single       Graduate
# ..          ...  ...        ...        ...            ...            ...
# 995         995   31       Pune        NaN        Married       Graduate
# 996         996   29       Pune        NaN        Married  Post Graduate
# 997         997   30     Mumbai   Business         Single       Graduate
# 998         998   24  Ahmedabad        NaN        Married       Graduate
# 999         999   30       Pune   Business         Single       Graduate
#
#      No. of Family members  Annual Income  \
# 0                        5   1.193876e+06
# 1                        4   1.844540e+06
# 2                        4   2.948150e+06
# 3                        3   2.832380e+06
# 4                        4   2.638751e+06
# ..                     ...            ...
# 995                      7   2.110722e+06
# 996                      4   1.616288e+06
# 997                      4   2.202829e+06
# 998                      4   1.764744e+06
# 999                      4   2.486664e+06
#
#     Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                Maybe
# 1                                                  Yes
# 2                                                  Yes
# 3                                                Maybe
# 4                                                  Yes
# ..                                                 ...
# 995                                                Yes
# 996                                                 No
# 997                                                Yes
# 998                                                Yes
# 999                                                 No
#
#     If Yes/Maybe what type of  EV would you prefer?  \
# 0                                               SUV
# 1                                               SUV
# 2                                         Hatchback
# 3                                         Hatchback
# 4                                             Sedan
# ..                                              ...
# 995                                             SUV
# 996                                             SUV
# 997                                             SUV
# 998                                             SUV
# 999                                        Liftback
#
#     Do you think Electronic Vehicles are economical?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
# ..                                               ...
# 995                                              Yes
# 996                                              Yes
# 997                                              Yes
# 998                                              Yes
# 999                                              Yes
#
#     Which brand of vehicle do you currently own?  \
# 0                                        Hyundai
# 1                                          Honda
# 2                                            KIA
# 3                                        Hyundai
# 4                                       McLaren
# ..                                           ...
# 995                                          KIA
# 996                                          KIA
# 997                                        Honda
# 998                                       Maruti
# 999                                      Maruti
#
#     How much money could you spend on an Electronic vehicle?  \
# 0                                             <5 lakhs
# 1                                            <15 lakhs
# 2                                            <15 lakhs
# 3                                             <5 lakhs
# 4                                            <15 lakhs
# ..                                                 ...
# 995                                          <25 lakhs
# 996                                           <5 lakhs
# 997                                          <15 lakhs
# 998                                          <15 lakhs
# 999                                           <5 lakhs
#
#      Preference for wheels in EV  \
# 0                              2
# 1                              4
# 2                              4
# 3                              4
# 4                              4
# ..                           ...
# 995                            4
# 996                            4
# 997                            4
# 998                            4
# 999                            4
#
#     Do you think Electronic vehicles will replace fuel cars in India?
# 0                                     I don't think so
# 1                                     Yes, in <20years
# 2                                     Yes, in <20years
# 3                                    Yes, in <10 years
# 4                                     Yes, in <20years
# ..                                                 ...
# 995                                  Yes, in <10 years
# 996                                   Yes, in <20years
# 997                                   Yes, in <20years
# 998                                   Yes, in <20years
# 999                                  Yes, in <10 years
#
# [1000 rows x 15 columns]

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.head(3)
# Out:
#    Unnamed: 0  Age       City Profession Marital Status Education  \
# 0           0   30      Nabha        NaN         Single  Graduate
# 1           1   27       Pune        NaN         Single  Graduate
# 2           2   32  Kashipur         NaN         Single  Graduate
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years

# %%
df.tail(3)
# Out:
#      Unnamed: 0  Age       City Profession Marital Status Education  \
# 997         997   30     Mumbai   Business         Single  Graduate
# 998         998   24  Ahmedabad        NaN        Married  Graduate
# 999         999   30       Pune   Business         Single  Graduate
#
#      No. of Family members  Annual Income  \
# 997                      4   2.202829e+06
# 998                      4   1.764744e+06
# 999                      4   2.486664e+06
#
#     Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 997                                                Yes
# 998                                                Yes
# 999                                                 No
#
#     If Yes/Maybe what type of  EV would you prefer?  \
# 997                                             SUV
# 998                                             SUV
# 999                                        Liftback
#
#     Do you think Electronic Vehicles are economical?  \
# 997                                              Yes
# 998                                              Yes
# 999                                              Yes
#
#     Which brand of vehicle do you currently own?  \
# 997                                        Honda
# 998                                       Maruti
# 999                                      Maruti
#
#     How much money could you spend on an Electronic vehicle?  \
# 997                                          <15 lakhs
# 998                                          <15 lakhs
# 999                                           <5 lakhs
#
#      Preference for wheels in EV  \
# 997                            4
# 998                            4
# 999                            4
#
#     Do you think Electronic vehicles will replace fuel cars in India?
# 997                                   Yes, in <20years
# 998                                   Yes, in <20years
# 999                                  Yes, in <10 years

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Unnamed: 0                                                            1000 non-null   int64
#  1   Age                                                                   1000 non-null   int64
#  2   City                                                                  1000 non-null   object
#  3   Profession                                                            540 non-null    object
#  4   Marital Status                                                        1000 non-null   object
#  5   Education                                                             1000 non-null   object
#  6   No. of Family members                                                 1000 non-null   int64
#  7   Annual Income                                                         1000 non-null   float64
#  8   Would you prefer replacing all your vehicles to Electronic vehicles?  1000 non-null   object
#  9   If Yes/Maybe what type of  EV would you prefer?                       1000 non-null   object
#  10  Do you think Electronic Vehicles are economical?                      1000 non-null   object
#  11  Which brand of vehicle do you currently own?                          1000 non-null   object
#  12  How much money could you spend on an Electronic vehicle?              1000 non-null   object
#  13  Preference for wheels in EV                                           1000 non-null   int64
#  14  Do you think Electronic vehicles will replace fuel cars in India?     1000 non-null   object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 117.3+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0          Age  No. of Family members  Annual Income  \
# count  1000.000000  1000.000000            1000.000000   1.000000e+03
# mean    499.500000    31.800000               4.118000   2.258342e+06
# std     288.819436    11.294847               1.469774   9.993558e+05
# min       0.000000    15.000000               0.000000  -3.761509e+05
# 25%     249.750000    26.000000               4.000000   1.782116e+06
# 50%     499.500000    29.000000               4.000000   2.329246e+06
# 75%     749.250000    31.000000               5.000000   2.753170e+06
# max     999.000000   118.000000               8.000000   1.282128e+07
#
#        Preference for wheels in EV
# count                  1000.000000
# mean                      3.349000
# std                       0.887686
# min                       2.000000
# 25%                       2.000000
# 50%                       4.000000
# 75%                       4.000000
# max                       4.000000

# %%
df.describe(include='object')
# Out:
#         City            Profession Marital Status Education  \
# count   1000                   540           1000      1000
# unique    35                     3              2         2
# top     Pune  Working Professional         Single  Graduate
# freq     570                   336            638       693
#
#        Would you prefer replacing all your vehicles to Electronic vehicles?  \
# count                                                1000
# unique                                                  3
# top                                                   Yes
# freq                                                  663
#
#        If Yes/Maybe what type of  EV would you prefer?  \
# count                                             1000
# unique                                               5
# top                                                SUV
# freq                                               467
#
#        Do you think Electronic Vehicles are economical?  \
# count                                              1000
# unique                                                3
# top                                                 Yes
# freq                                                768
#
#        Which brand of vehicle do you currently own?  \
# count                                          1000
# unique                                           16
# top                                            Tata
# freq                                            186
#
#        How much money could you spend on an Electronic vehicle?  \
# count                                                1000
# unique                                                  8
# top                                             <15 lakhs
# freq                                                  483
#
#        Do you think Electronic vehicles will replace fuel cars in India?
# count                                                1000
# unique                                                  4
# top                                     Yes, in <10 years
# freq                                                  419

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'City', 'Profession', 'Marital Status',
#        'Education', 'No. of Family members', 'Annual Income',
#        'Would you prefer replacing all your vehicles to Electronic vehicles?',
#        'If Yes/Maybe what type of  EV would you prefer?',
#        'Do you think Electronic Vehicles are economical?',
#        'Which brand of vehicle do you currently own?',
#        'How much money could you spend on an Electronic vehicle?',
#        'Preference for wheels in EV',
#        'Do you think Electronic vehicles will replace fuel cars in India?'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0',axis=1)
df
# Out:
#      Age       City Profession Marital Status      Education  \
# 0     30      Nabha        NaN         Single       Graduate
# 1     27       Pune        NaN         Single       Graduate
# 2     32  Kashipur         NaN         Single       Graduate
# 3     55       Pune   Business         Single       Graduate
# 4     26     Satara        NaN         Single       Graduate
# ..   ...        ...        ...            ...            ...
# 995   31       Pune        NaN        Married       Graduate
# 996   29       Pune        NaN        Married  Post Graduate
# 997   30     Mumbai   Business         Single       Graduate
# 998   24  Ahmedabad        NaN        Married       Graduate
# 999   30       Pune   Business         Single       Graduate
#
#      No. of Family members  Annual Income  \
# 0                        5   1.193876e+06
# 1                        4   1.844540e+06
# 2                        4   2.948150e+06
# 3                        3   2.832380e+06
# 4                        4   2.638751e+06
# ..                     ...            ...
# 995                      7   2.110722e+06
# 996                      4   1.616288e+06
# 997                      4   2.202829e+06
# 998                      4   1.764744e+06
# 999                      4   2.486664e+06
#
#     Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                Maybe
# 1                                                  Yes
# 2                                                  Yes
# 3                                                Maybe
# 4                                                  Yes
# ..                                                 ...
# 995                                                Yes
# 996                                                 No
# 997                                                Yes
# 998                                                Yes
# 999                                                 No
#
#     If Yes/Maybe what type of  EV would you prefer?  \
# 0                                               SUV
# 1                                               SUV
# 2                                         Hatchback
# 3                                         Hatchback
# 4                                             Sedan
# ..                                              ...
# 995                                             SUV
# 996                                             SUV
# 997                                             SUV
# 998                                             SUV
# 999                                        Liftback
#
#     Do you think Electronic Vehicles are economical?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
# ..                                               ...
# 995                                              Yes
# 996                                              Yes
# 997                                              Yes
# 998                                              Yes
# 999                                              Yes
#
#     Which brand of vehicle do you currently own?  \
# 0                                        Hyundai
# 1                                          Honda
# 2                                            KIA
# 3                                        Hyundai
# 4                                       McLaren
# ..                                           ...
# 995                                          KIA
# 996                                          KIA
# 997                                        Honda
# 998                                       Maruti
# 999                                      Maruti
#
#     How much money could you spend on an Electronic vehicle?  \
# 0                                             <5 lakhs
# 1                                            <15 lakhs
# 2                                            <15 lakhs
# 3                                             <5 lakhs
# 4                                            <15 lakhs
# ..                                                 ...
# 995                                          <25 lakhs
# 996                                           <5 lakhs
# 997                                          <15 lakhs
# 998                                          <15 lakhs
# 999                                           <5 lakhs
#
#      Preference for wheels in EV  \
# 0                              2
# 1                              4
# 2                              4
# 3                              4
# 4                              4
# ..                           ...
# 995                            4
# 996                            4
# 997                            4
# 998                            4
# 999                            4
#
#     Do you think Electronic vehicles will replace fuel cars in India?
# 0                                     I don't think so
# 1                                     Yes, in <20years
# 2                                     Yes, in <20years
# 3                                    Yes, in <10 years
# 4                                     Yes, in <20years
# ..                                                 ...
# 995                                  Yes, in <10 years
# 996                                   Yes, in <20years
# 997                                   Yes, in <20years
# 998                                   Yes, in <20years
# 999                                  Yes, in <10 years
#
# [1000 rows x 14 columns]

# %%
df.head()
# Out:
#    Age       City Profession Marital Status Education  No. of Family members  \
# 0   30      Nabha        NaN         Single  Graduate                      5
# 1   27       Pune        NaN         Single  Graduate                      4
# 2   32  Kashipur         NaN         Single  Graduate                      4
# 3   55       Pune   Business         Single  Graduate                      3
# 4   26     Satara        NaN         Single  Graduate                      4
#
#    Annual Income  \
# 0   1.193876e+06
# 1   1.844540e+06
# 2   2.948150e+06
# 3   2.832380e+06
# 4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years

# %%
df.isnull().sum()
# Out:
# Age                                                                       0
# City                                                                      0
# Profession                                                              460
# Marital Status                                                            0
# Education                                                                 0
# No. of Family members                                                     0
# Annual Income                                                             0
# Would you prefer replacing all your vehicles to Electronic vehicles?      0
# If Yes/Maybe what type of  EV would you prefer?                           0
# Do you think Electronic Vehicles are economical?                          0
# Which brand of vehicle do you currently own?                              0
# How much money could you spend on an Electronic vehicle?                  0
# Preference for wheels in EV                                               0
# Do you think Electronic vehicles will replace fuel cars in India?         0
# dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
sns.color_palette("viridis", as_cmap=True)
plt.title('Correlation Matrix')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                                   Age  No. of Family members  Annual Income  \
# Age                          1.000000               0.023914      -0.012452
# No. of Family members        0.023914               1.000000       0.027894
# Annual Income               -0.012452               0.027894       1.000000
# Preference for wheels in EV  0.028134              -0.020855      -0.023151
#
#                              Preference for wheels in EV
# Age                                             0.028134
# No. of Family members                          -0.020855
# Annual Income                                  -0.023151
# Preference for wheels in EV                     1.000000

# %%
fig,axes = plt.subplots(2,2,figsize=(10,10))
sns.histplot(data=df, x='Age', kde=True, color='blue',ax=axes[0,0])
sns.histplot(data=df, x='No. of Family members', kde=True, color='purple',ax=axes[0,1])
sns.histplot(data=df, x='Annual Income', kde=True, color='red',ax=axes[1,0])
sns.histplot(data=df, x='Preference for wheels in EV', kde=True, color='green',ax=axes[1,1])
# Out:
# <Axes: xlabel='Preference for wheels in EV', ylabel='Count'>

# %%
plt.figure(figsize=(6,6))
plt.pie(df['Profession'].value_counts(),autopct='%1.1f%%')
plt.title('Distribution of Profession')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(df['Marital Status'].value_counts(),autopct='%1.1f%%')
plt.title('Distribution of Marital Status')
plt.ylabel('')
plt.show()

# %%
# Unique Cities
df['City'].unique()
# Out:
# array(['Nabha', 'Pune', 'Kashipur ', 'Satara', 'Noida', 'Delhi', 'Mumbai',
#        'pune', 'solapur', 'Haldwani ', 'Nellore ', 'Pune ', 'Haldwani',
#        'Banglore ', 'Faridabad ', 'Nagpur', 'Chandrapur ', 'Chennai',
#        'Gurugram ', 'Nashik', 'Bengaluru', 'Mumbai ', 'Hakdwani',
#        'Patiyala', 'pUNE', 'Ahmedabad', 'Karnal', 'Rewari', 'New Delhi',
#        'Serampore', 'Jhansi', 'New Delhi ', 'Jalandhar', 'Delhi ',
#        'nashik'], dtype=object)

# %%
# Standardizes city names in the 'City' column of DataFrame 'df'.
df["City"] = df["City"].replace({"Pune ": "Pune", "pUNE": "Pune", "pune": "Pune", "Pune": "Pune"})
df["City"] = df["City"].replace({"Banglore ": "Bengaluru"})
df["City"] = df["City"].replace({"Hakdwani": "Haldwani", "Haldwani ": "Haldwani"})
df["City"] = df["City"].replace({"New Delhi ": "Delhi", "Delhi ": "Delhi"})
df["City"] = df["City"].replace({"nashik": "Nashik"})
df["City"] = df["City"].replace({"Mumbai ": "Mumbai"})

# %%
# Finding again unique cities
df['City'].unique()
# Out:
# array(['Nabha', 'Pune', 'Kashipur ', 'Satara', 'Noida', 'Delhi', 'Mumbai',
#        'solapur', 'Haldwani', 'Nellore ', 'Bengaluru', 'Faridabad ',
#        'Nagpur', 'Chandrapur ', 'Chennai', 'Gurugram ', 'Nashik',
#        'Patiyala', 'Ahmedabad', 'Karnal', 'Rewari', 'New Delhi',
#        'Serampore', 'Jhansi', 'Jalandhar'], dtype=object)

# %%
# Count plot of top 5 cities
sns.countplot(x='City', data=df, order=df['City'].value_counts().iloc[:5].index)
plt.title('Top 5 cities')
plt.xlabel('City')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6,6))
df['No. of Family members'].value_counts().plot(kind="bar",color='orange')
plt.title('Number of family members')
plt.xlabel('Number of family numbers')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(6,6))
df['Education'].value_counts().plot(kind='bar',color='olive')
plt.title('Distribution of education')
plt.xlabel('Education')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(6,6))
df['Do you think Electronic Vehicles are economical?'].value_counts().plot(kind='bar', color = 'yellow')
plt.title('Evaluating the economic aspects of EV')
plt.ylabel('Count')
plt.xlabel('Respones')
# Out:
# Text(0.5, 0, 'Respones')

# %% [raw]
# In this graph it shows responses to a survey or question about the economic aspects of electric vehicles (EVs)

# %%
plt.figure(figsize=(6,6)) # Set the figsize to (6,6) inches

df['How much money could you spend on an Electronic vehicle?'].value_counts().plot(kind='bar',color='brown') #Plotting bar chart
plt.title('Spending Capacity on an Electronic Vehicle')
plt.xlabel('Spending Range')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [raw]
# In this graph shows that max number of people can spend less than 15 lakhs for EV.

# %%
plt.figure(figsize=(6,6))
df['Which brand of vehicle do you currently own?'].value_counts().plot(kind='bar',color='aqua') # Plotting bar chart
plt.title('Current Vehicle Ownership by Brand')
plt.xlabel('Vehicle brand')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [raw]
# It this graph shows the count of vehicle ownership for various brands. The x-axis represents different vehicle brands, and the y-axis represents the count of vehicles owned.

# %%
plt.figure(figsize=(18,6)) #Set the plot size
sns.countplot(x='Age',data=df,hue='Education') # Plotting count plot
plt.title('Count of education by Age')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [raw]
# In this graph it shows that the most of the people are in the age grouph of 24 to 32 and they are graduates.

# %%
plt.figure(figsize=(18, 6))
sns.countplot(x='Education', data=df, hue='Do you think Electronic Vehicles are economical?')
plt.title('Distribution of Perception on Electric Vehicle Economy across Education Levels')
plt.xlabel('Education')
plt.ylabel('Count')
plt.legend(title='Perception of EV Economy')

# %% [raw]
# In this graph it shows that the chart compares the perceptions of electric vehicle (EV) economy among individuals with different education levels: Graduate and Post Graduate.

# %%
plt.figure(figsize=(18, 6))
sns.countplot(x='No. of Family members', data=df, hue='Do you think Electronic Vehicles are economical?')
plt.title('Perception of Electric Vehicle Economy Based on Family Size')
plt.xlabel('Number of Family Members')
plt.ylabel('Count')
plt.legend(title='Perception of EV Economy')

# %% [raw]
# The chart shows the distribution of perceptions of electric vehicle economy across different family sizes.

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x="Which brand of vehicle do you currently own?", data=df, hue="Profession")
plt.title('Vehicle Brand Ownership Across Professions')
plt.xlabel('Vehicle Brands')
plt.ylabel('Count')
plt.legend(title='Profession')
plt.tight_layout()  # Adjust layout to prevent overlapping

# %% [raw]
# It shows the count of vehicle brand ownership among three different professions: Business, Working Professional, and Salaried.

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoder(data,column):
    label_encoder=LabelEncoder()
    return label_encoder.fit_transform(data[column].astype(str))

# %%
df.head()
# Out:
#    Unnamed: 0  Age       City Profession Marital Status Education  \
# 0           0   30      Nabha        NaN         Single  Graduate
# 1           1   27       Pune        NaN         Single  Graduate
# 2           2   32  Kashipur         NaN         Single  Graduate
# 3           3   55       Pune   Business         Single  Graduate
# 4           4   26     Satara        NaN         Single  Graduate
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#   Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                              Maybe
# 1                                                Yes
# 2                                                Yes
# 3                                              Maybe
# 4                                                Yes
#
#   If Yes/Maybe what type of  EV would you prefer?  \
# 0                                             SUV
# 1                                             SUV
# 2                                       Hatchback
# 3                                       Hatchback
# 4                                           Sedan
#
#   Do you think Electronic Vehicles are economical?  \
# 0                                              Yes
# 1                                              Yes
# 2                                              Yes
# 3                                               No
# 4                                              Yes
#
#   Which brand of vehicle do you currently own?  \
# 0                                      Hyundai
# 1                                        Honda
# 2                                          KIA
# 3                                      Hyundai
# 4                                     McLaren
#
#   How much money could you spend on an Electronic vehicle?  \
# 0                                           <5 lakhs
# 1                                          <15 lakhs
# 2                                          <15 lakhs
# 3                                           <5 lakhs
# 4                                          <15 lakhs
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#   Do you think Electronic vehicles will replace fuel cars in India?
# 0                                   I don't think so
# 1                                   Yes, in <20years
# 2                                   Yes, in <20years
# 3                                  Yes, in <10 years
# 4                                   Yes, in <20years

# %%
# Encoding categorical columns
df['City']= label_encoder(df,'City')
df['Profession']= label_encoder(df,'Profession')
df['Marital Status']= label_encoder(df,'Marital Status')
df['Education']= label_encoder(df,'Education')

# %%
# Encoding all the columns
df['Would you prefer replacing all your vehicles to Electronic vehicles?']= label_encoder(df,'Would you prefer replacing all your vehicles to Electronic vehicles?')
df['If Yes/Maybe what type of  EV would you prefer?']= label_encoder(df,'If Yes/Maybe what type of  EV would you prefer?')
df['Do you think Electronic Vehicles are economical?']= label_encoder(df,'Do you think Electronic Vehicles are economical?')
df['Which brand of vehicle do you currently own?']= label_encoder(df,'Which brand of vehicle do you currently own?')
df['Do you think Electronic vehicles will replace fuel cars in India?']= label_encoder(df,'Do you think Electronic vehicles will replace fuel cars in India?')
df['How much money could you spend on an Electronic vehicle?']= label_encoder(df,'How much money could you spend on an Electronic vehicle?')
df.head()
# Out:
#    Unnamed: 0  Age  City  Profession  Marital Status  Education  \
# 0           0   30    18           3               1          0
# 1           1   27    26           3               1          0
# 2           2   32    15           3               1          0
# 3           3   55    26           0               1          0
# 4           4   26    29           3               1          0
#
#    No. of Family members  Annual Income  \
# 0                      5   1.193876e+06
# 1                      4   1.844540e+06
# 2                      4   2.948150e+06
# 3                      3   2.832380e+06
# 4                      4   2.638751e+06
#
#    Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  2
#
#    If Yes/Maybe what type of  EV would you prefer?  \
# 0                                                3
# 1                                                3
# 2                                                1
# 3                                                1
# 4                                                4
#
#    Do you think Electronic Vehicles are economical?  \
# 0                                                 2
# 1                                                 2
# 2                                                 2
# 3                                                 1
# 4                                                 2
#
#    Which brand of vehicle do you currently own?  \
# 0                                             4
# 1                                             3
# 2                                             5
# 3                                             4
# 4                                            10
#
#    How much money could you spend on an Electronic vehicle?  \
# 0                                                  6
# 1                                                  4
# 2                                                  4
# 3                                                  6
# 4                                                  4
#
#    Preference for wheels in EV  \
# 0                            2
# 1                            4
# 2                            4
# 3                            4
# 4                            4
#
#    Do you think Electronic vehicles will replace fuel cars in India?
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2

# %%
# Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Feature and target selection
# Replace 'features' with the names of the independent variables and 'target_column' with the target column
X = df[['Age', 'Would you prefer replacing all your vehicles to Electronic vehicles?', 'How much money could you spend on an Electronic vehicle?','Annual Income']]  # Replace with actual feature columns
y = df['Do you think Electronic vehicles will replace fuel cars in India?']  # Replace 'Target' with your actual target column

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Training the Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

# Making predictions
y_pred = dt_model.predict(X_test)

# Evaluating the model
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[ 1  6  3  4]
#  [12 62 36 16]
#  [12 44 47 16]
#  [ 2 21 15  3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.04      0.07      0.05        14
#            1       0.47      0.49      0.48       126
#            2       0.47      0.39      0.43       119
#            3       0.08      0.07      0.07        41
#
#     accuracy                           0.38       300
#    macro avg       0.26      0.26      0.26       300
# weighted avg       0.39      0.38      0.38       300
#
#
# Accuracy Score: 0.37666666666666665

# %%
# Importing required libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# Feature scaling (important for KNN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Training the K-Nearest Neighbors model
knn_model = KNeighborsClassifier(n_neighbors=5)  # Adjust 'n_neighbors' if needed
knn_model.fit(X_train, y_train)

# Making predictions
y_pred = knn_model.predict(X_test)

# Evaluating the model
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.46      0.61      0.52       126
#            2       0.46      0.44      0.45       119
#            3       0.00      0.00      0.00        41
#
#     accuracy                           0.43       300
#    macro avg       0.23      0.26      0.24       300
# weighted avg       0.37      0.43      0.40       300
#
#
# Accuracy Score: 0.43

# %%
from sklearn import svm

# initialize the SVM clssifier 
clf = svm.SVC(kernel='linear', C = 1, gamma='auto')

# Fit the classifier to the training
clf.fit(X_train,y_train)

# Predict on the testin data
y_pred = clf.predict(X_test)

# Print the accuracy score
print('Accuracy:',clf.score(X_test,y_test))
# Out:
# Accuracy: 0.42333333333333334

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
print('Accuracy:',classifier.score(X_test,y_test))
# Out:
# Accuracy: 0.42
